# %% [markdown]
# In this research paper:
# https://arxiv.org/ftp/arxiv/papers/1907/1907.07901.pdf
#
# I have found the skin rolling data augmentation technique that we will use as we do not have enough data, data augmentation will help us to further increase the accuracy of the model. It is also important to apply this technique because the severity of acne does not depend on where the acne lesion is. Instead, it is mostly determined by the severity of each acne lesion, and how many there are.

# %% [markdown]
# **Demonstrating the skin patch rolling:**

# %%
def roll_and_plot(img, file_name_wo_ext, x_or_y, pixels, verb):
    img_height, img_width = img.shape[0:2]
    img2 = copy.copy(img)
    if x_or_y == 'x':
        img2[:, 0:(img_width-pixels),:] = img[:,pixels:img_width,:]
        img2[:,(img_width-pixels):img_width,:] = img[:,0:pixels,:]
    else:
        img2[0:(img_height-pixels), :, :] = img[pixels:img_height, :, :]
        img2[(img_height-pixels):img_height, :,:] = img[0:pixels,:, :]
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)        

    if verb:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        f, axarr = plt.subplots(2,1)
        axarr[0].imshow(img)
        axarr[1].imshow(img2)
    return

roll_ratio = 2
num_times = 1


patch_image_path = '/content/drive/MyDrive/TestingNewModel/nestle-acne-assessment/data/demo_images_patches/47-472215_emilia-clarke-ultra-hd-wallpaper-front-emilia-clarke_fh.jpg'
img = cv2.imread(patch_image_path)

img_height, img_width = img.shape[0:2]

# dertermine the rolling direction
if 'fh' in patch_image_name: 
    x_or_y = 'x'
else: 
    x_or_y = 'y'

# dertermine rolling step size
if x_or_y == 'x':
    step_size = int(np.floor(np.float(img_width)/np.float(num_times+1))) 
else:
    step_size = int(np.floor(np.float(img_height)/np.float(num_times+1)))

    
for j in range(num_times):
    image_names = roll_and_plot(img, image_name_no_ext, x_or_y, step_size*(j+1), True)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img1 = mpimg.imread(r"C:\Users\Sana Shah\Desktop\nestle acne\Augmented_patches\5-Very_Severe\levle3_4_lc_roll_y_0.jpg")
img2 = mpimg.imread(r"C:\Users\Sana Shah\Desktop\nestle acne\Augmented_patches\5-Very_Severe\levle3_4_lc_roll_y_141.jpg")

fig, (ax1,ax2) = plt.subplots(nrows=2,ncols=1,figsize=(15,10))

ax1.imshow(img1)
ax2.imshow(img2)

# %%
img1 = mpimg.imread(r"C:\Users\Sana Shah\Desktop\nestle acne\Augmented_patches\1-Clear\779_rc_roll_y_121.jpg")
img2 = mpimg.imread(r"C:\Users\Sana Shah\Desktop\nestle acne\Augmented_patches\1-Clear\779_rc_roll_y_0.jpg")

fig, (ax1,ax2) = plt.subplots(nrows=2,ncols=1,figsize=(15,10))

ax1.imshow(img2)
ax2.imshow(img1)
